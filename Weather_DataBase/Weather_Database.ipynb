# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from datetime import datetime
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 753

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# # Deliverable 1

# %%
# Create an empty list to hold the weather data.
city_data = []


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
  
    #Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1


# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | waipawa
# Processing Record 3 of Set 1 | pierre
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | maryborough
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | vila franca do campo
# Processing Record 10 of Set 1 | black river
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | menden
# Processing Record 13 of Set 1 | lethem
# Processing Record 14 of Set 1 | bani walid
# Processing Record 15 of Set 1 | bathsheba
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | papetoai
# Processing Record 27 of Set 1 | lamar
# Processing Record 28 of Set 1 | santiago
# Processing Record 29 of Set 1 | bogorodskoye
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | vestmannaeyjar
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | ordzhonikidze
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | brae
# Processing Record 37 of Set 1 | isangel
# Processing Record 38 of Set 1 | san quintin
# Processing Record 39 of Set 1 | dinan
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | tocopilla
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | athabasca
# Processing Record 46 of Set 1 | alta floresta
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | greenwood
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | sao gabriel da cachoeira
# Processing Record 1 of Set 2 | kenai
# Processing Record 2 of Set 2 | college
# Processing Record 3 of Set 2 | okhotsk
# Processing Record 4 of Set 2 | goundi
# Processing Record 5 of Set 2 | yokadouma
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | muros
# Processing Record 8 of Set 2 | chuka
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | maragogi
# Processing Record 11 of Set 2 | maues
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | constitucion
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 2 | glogow
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | rawson
# Processing Record 18 of Set 2 | flinders
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | namibe
# Processing Record 23 of Set 2 | beringovskiy
# Processing Record 24 of Set 2 | isla mujeres
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | kamenka
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | fuyu
# Processing Record 31 of Set 2 | morondava
# Processing Record 32 of Set 2 | north bend
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | acarau
# Processing Record 37 of Set 2 | neryungri
# Processing Record 38 of Set 2 | verkhoyansk
# Processing Record 39 of Set 2 | oxford
# Processing Record 40 of Set 2 | lavrentiya
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | zyryanka
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | oistins
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | comodoro rivadavia
# Processing Record 50 of Set 2 | acapulco
# Processing Record 1 of Set 3 | nokaneng
# Processing Record 2 of Set 3 | tadine
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | yeniseysk
# Processing Record 8 of Set 3 | chernyshevskiy
# Processing Record 9 of Set 3 | afyonkarahisar
# Processing Record 10 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 3 | lorengau
# Processing Record 12 of Set 3 | san joaquin
# Processing Record 13 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 3 | trojes
# Processing Record 15 of Set 3 | cabedelo
# Processing Record 16 of Set 3 | andapa
# Processing Record 17 of Set 3 | fuling
# Processing Record 18 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 3 | cabo san lucas
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | novyy yarychiv
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | churapcha
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | seoul
# Processing Record 26 of Set 3 | burica
# City not found. Skipping...
# Processing Record 27 of Set 3 | andenes
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | shingu
# Processing Record 32 of Set 3 | valleyview
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | kuvshinovo
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | goias
# Processing Record 37 of Set 3 | oranjemund
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | baruun-urt
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | luanda
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 3 | omsukchan
# Processing Record 45 of Set 3 | yarkovo
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | hanna
# Processing Record 48 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 3 | pecanha
# Processing Record 50 of Set 3 | ramapuram
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | chaman
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | mehamn
# Processing Record 5 of Set 4 | yamada
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | ancud
# Processing Record 8 of Set 4 | kars
# Processing Record 9 of Set 4 | pakxan
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | balkanabat
# Processing Record 12 of Set 4 | gainesville
# Processing Record 13 of Set 4 | fuyang
# Processing Record 14 of Set 4 | rio verde de mato grosso
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | olafsvik
# Processing Record 17 of Set 4 | benghazi
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | madang
# Processing Record 20 of Set 4 | buala
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | aykhal
# Processing Record 23 of Set 4 | palmas de monte alto
# Processing Record 24 of Set 4 | yumen
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 4 | faya
# Processing Record 29 of Set 4 | ouadda
# Processing Record 30 of Set 4 | san francisco
# Processing Record 31 of Set 4 | vanavara
# Processing Record 32 of Set 4 | talcahuano
# Processing Record 33 of Set 4 | asau
# Processing Record 34 of Set 4 | alakurtti
# Processing Record 35 of Set 4 | tasiilaq
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | khuzhir
# Processing Record 38 of Set 4 | bac lieu
# Processing Record 39 of Set 4 | chipinge
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | labuhan
# Processing Record 42 of Set 4 | nome
# Processing Record 43 of Set 4 | cayenne
# Processing Record 44 of Set 4 | pathalgaon
# Processing Record 45 of Set 4 | tazovskiy
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | tessalit
# Processing Record 50 of Set 4 | zafra
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | de-kastri
# Processing Record 4 of Set 5 | asadabad
# Processing Record 5 of Set 5 | cidreira
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | jenbach
# Processing Record 8 of Set 5 | coruripe
# Processing Record 9 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 5 | lata
# Processing Record 11 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 5 | llangefni
# Processing Record 14 of Set 5 | biltine
# Processing Record 15 of Set 5 | axim
# Processing Record 16 of Set 5 | aksarka
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | santo augusto
# Processing Record 19 of Set 5 | ust-maya
# Processing Record 20 of Set 5 | alice town
# Processing Record 21 of Set 5 | mount pleasant
# Processing Record 22 of Set 5 | peniche
# Processing Record 23 of Set 5 | muroto
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | miranda de ebro
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | komsomolskiy
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | barstow
# Processing Record 31 of Set 5 | sur
# Processing Record 32 of Set 5 | vardo
# Processing Record 33 of Set 5 | maua
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | quelimane
# Processing Record 36 of Set 5 | guanica
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | montague
# Processing Record 39 of Set 5 | malakal
# Processing Record 40 of Set 5 | nacunday
# City not found. Skipping...
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | kaputa
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | garden city
# Processing Record 45 of Set 5 | weinan
# Processing Record 46 of Set 5 | westport
# Processing Record 47 of Set 5 | itarema
# Processing Record 48 of Set 5 | vilhena
# Processing Record 49 of Set 5 | hamilton
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | ahipara
# Processing Record 2 of Set 6 | murgab
# Processing Record 3 of Set 6 | bikaner
# Processing Record 4 of Set 6 | kununurra
# Processing Record 5 of Set 6 | busing
# Processing Record 6 of Set 6 | dilla
# Processing Record 7 of Set 6 | bonthe
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | igarka
# Processing Record 10 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 6 | luganville
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | makakilo city
# Processing Record 14 of Set 6 | san vicente
# Processing Record 15 of Set 6 | kasama
# Processing Record 16 of Set 6 | bingol
# Processing Record 17 of Set 6 | nabire
# Processing Record 18 of Set 6 | rochelle
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | cururupu
# Processing Record 21 of Set 6 | marsa matruh
# Processing Record 22 of Set 6 | umm kaddadah
# Processing Record 23 of Set 6 | madimba
# Processing Record 24 of Set 6 | nioki
# Processing Record 25 of Set 6 | kaduna
# Processing Record 26 of Set 6 | batagay-alyta
# Processing Record 27 of Set 6 | fairbanks
# Processing Record 28 of Set 6 | macusani
# Processing Record 29 of Set 6 | chapais
# Processing Record 30 of Set 6 | marijampole
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | arman
# Processing Record 33 of Set 6 | inirida
# Processing Record 34 of Set 6 | rochester
# Processing Record 35 of Set 6 | vila velha
# Processing Record 36 of Set 6 | ixtapa
# Processing Record 37 of Set 6 | maputo
# Processing Record 38 of Set 6 | maymanak
# City not found. Skipping...
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | sept-iles
# Processing Record 42 of Set 6 | tooele
# Processing Record 43 of Set 6 | scarborough
# Processing Record 44 of Set 6 | ranau
# Processing Record 45 of Set 6 | mayumba
# Processing Record 46 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 6 | krasnoselkup
# Processing Record 48 of Set 6 | warwick
# Processing Record 49 of Set 6 | saint-georges
# Processing Record 50 of Set 6 | winslow
# Processing Record 1 of Set 7 | port hardy
# Processing Record 2 of Set 7 | gornopravdinsk
# Processing Record 3 of Set 7 | mbandaka
# Processing Record 4 of Set 7 | dakar
# Processing Record 5 of Set 7 | namanga
# Processing Record 6 of Set 7 | castro
# Processing Record 7 of Set 7 | tanabe
# Processing Record 8 of Set 7 | teguldet
# Processing Record 9 of Set 7 | lodja
# Processing Record 10 of Set 7 | bengkulu
# Processing Record 11 of Set 7 | state college
# Processing Record 12 of Set 7 | berlevag
# Processing Record 13 of Set 7 | lebu
# Processing Record 14 of Set 7 | boca do acre
# Processing Record 15 of Set 7 | mykolayivka
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | saint-joseph
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | silver city
# Processing Record 20 of Set 7 | shymkent
# Processing Record 21 of Set 7 | beasain
# Processing Record 22 of Set 7 | kuching
# Processing Record 23 of Set 7 | pilot butte
# Processing Record 24 of Set 7 | basyanovskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | shieli
# Processing Record 26 of Set 7 | trinidad
# Processing Record 27 of Set 7 | kaihua
# Processing Record 28 of Set 7 | saskylakh
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | iberia
# Processing Record 31 of Set 7 | puerto del rosario
# Processing Record 32 of Set 7 | pangnirtung
# Processing Record 33 of Set 7 | marienburg
# Processing Record 34 of Set 7 | sambava
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | ketchikan
# Processing Record 37 of Set 7 | alindao
# Processing Record 38 of Set 7 | zlitan
# Processing Record 39 of Set 7 | isla vista
# Processing Record 40 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 7 | juneau
# Processing Record 42 of Set 7 | kropotkin
# Processing Record 43 of Set 7 | nelson bay
# Processing Record 44 of Set 7 | pochutla
# Processing Record 45 of Set 7 | christchurch
# Processing Record 46 of Set 7 | windsor
# Processing Record 47 of Set 7 | tefe
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | srednekolymsk
# Processing Record 50 of Set 7 | redmond
# Processing Record 1 of Set 8 | barcelos
# Processing Record 2 of Set 8 | australind
# Processing Record 3 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 8 | dzaoudzi
# Processing Record 5 of Set 8 | wilmington
# Processing Record 6 of Set 8 | ishigaki
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 8 | sorong
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | mahebourg
# Processing Record 11 of Set 8 | koceljeva
# Processing Record 12 of Set 8 | tangermunde
# Processing Record 13 of Set 8 | shenzhen
# Processing Record 14 of Set 8 | yatou
# Processing Record 15 of Set 8 | kloulklubed
# Processing Record 16 of Set 8 | puerto escondido
# Processing Record 17 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 18 of Set 8 | sungaipenuh
# Processing Record 19 of Set 8 | camacha
# Processing Record 20 of Set 8 | agucadoura
# Processing Record 21 of Set 8 | khanpur
# Processing Record 22 of Set 8 | san patricio
# Processing Record 23 of Set 8 | roznava
# Processing Record 24 of Set 8 | castro verde
# Processing Record 25 of Set 8 | whitehorse
# Processing Record 26 of Set 8 | gillingham
# Processing Record 27 of Set 8 | samana
# Processing Record 28 of Set 8 | auki
# Processing Record 29 of Set 8 | lac-megantic
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | sao joao da barra
# Processing Record 32 of Set 8 | mutare
# Processing Record 33 of Set 8 | belmonte
# Processing Record 34 of Set 8 | la macarena
# Processing Record 35 of Set 8 | aloleng
# Processing Record 36 of Set 8 | codrington
# Processing Record 37 of Set 8 | shimoda
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | general pico
# Processing Record 40 of Set 8 | pacific grove
# Processing Record 41 of Set 8 | goderich
# Processing Record 42 of Set 8 | yanam
# Processing Record 43 of Set 8 | hovd
# Processing Record 44 of Set 8 | joensuu
# Processing Record 45 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 8 | sajoszentpeter
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | dawlatabad
# Processing Record 49 of Set 8 | paiho
# City not found. Skipping...
# Processing Record 50 of Set 8 | ugoofaaru
# Processing Record 1 of Set 9 | shache
# Processing Record 2 of Set 9 | kismayo
# Processing Record 3 of Set 9 | summerside
# Processing Record 4 of Set 9 | changli
# Processing Record 5 of Set 9 | pisco
# Processing Record 6 of Set 9 | ibra
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | panama city
# Processing Record 9 of Set 9 | yima
# Processing Record 10 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | ozark
# Processing Record 13 of Set 9 | jaque
# Processing Record 14 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 9 | hobyo
# Processing Record 16 of Set 9 | khani
# Processing Record 17 of Set 9 | chicama
# Processing Record 18 of Set 9 | shasta lake
# Processing Record 19 of Set 9 | port-cartier
# Processing Record 20 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 9 | tambura
# Processing Record 22 of Set 9 | cuenca
# Processing Record 23 of Set 9 | yashkul
# Processing Record 24 of Set 9 | aktash
# Processing Record 25 of Set 9 | ilulissat
# Processing Record 26 of Set 9 | amalapuram
# Processing Record 27 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 9 | luderitz
# Processing Record 29 of Set 9 | cherskiy
# Processing Record 30 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 31 of Set 9 | ostrovnoy
# Processing Record 32 of Set 9 | orotukan
# Processing Record 33 of Set 9 | ayan
# Processing Record 34 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 9 | ocos
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | laguna
# Processing Record 38 of Set 9 | marshfield
# Processing Record 39 of Set 9 | khatanga
# Processing Record 40 of Set 9 | karasjok
# Processing Record 41 of Set 9 | mount isa
# Processing Record 42 of Set 9 | pimentel
# Processing Record 43 of Set 9 | mpika
# Processing Record 44 of Set 9 | markala
# Processing Record 45 of Set 9 | hyeres
# Processing Record 46 of Set 9 | carbonia
# Processing Record 47 of Set 9 | kuito
# Processing Record 48 of Set 9 | fukue
# Processing Record 49 of Set 9 | ballina
# Processing Record 50 of Set 9 | ust-tsilma
# Processing Record 1 of Set 10 | asfi
# Processing Record 2 of Set 10 | cannes
# Processing Record 3 of Set 10 | kurayoshi
# Processing Record 4 of Set 10 | ambon
# Processing Record 5 of Set 10 | greeley
# Processing Record 6 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 10 | rio gallegos
# Processing Record 8 of Set 10 | havelock
# Processing Record 9 of Set 10 | doha
# Processing Record 10 of Set 10 | grande prairie
# Processing Record 11 of Set 10 | saint-gaudens
# Processing Record 12 of Set 10 | saint-ambroise
# Processing Record 13 of Set 10 | odemis
# City not found. Skipping...
# Processing Record 14 of Set 10 | wairoa
# Processing Record 15 of Set 10 | kalmunai
# Processing Record 16 of Set 10 | yulara
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | havre-saint-pierre
# Processing Record 19 of Set 10 | sao francisco de paula
# Processing Record 20 of Set 10 | yerbogachen
# Processing Record 21 of Set 10 | saiha
# Processing Record 22 of Set 10 | kirakira
# Processing Record 23 of Set 10 | smoky lake
# Processing Record 24 of Set 10 | sorland
# Processing Record 25 of Set 10 | pietarsaari
# Processing Record 26 of Set 10 | inongo
# Processing Record 27 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 10 | ipora
# Processing Record 29 of Set 10 | kangaatsiaq
# Processing Record 30 of Set 10 | samarai
# Processing Record 31 of Set 10 | little current
# Processing Record 32 of Set 10 | boissevain
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | santana do matos
# Processing Record 35 of Set 10 | bandarbeyla
# Processing Record 36 of Set 10 | nanakuli
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | podor
# Processing Record 39 of Set 10 | kawalu
# Processing Record 40 of Set 10 | pekan
# Processing Record 41 of Set 10 | port lincoln
# Processing Record 42 of Set 10 | padang
# Processing Record 43 of Set 10 | koubia
# Processing Record 44 of Set 10 | gundlupet
# Processing Record 45 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 10 | fort nelson
# Processing Record 47 of Set 10 | sistranda
# Processing Record 48 of Set 10 | marzuq
# Processing Record 49 of Set 10 | beloha
# Processing Record 50 of Set 10 | half moon bay
# Processing Record 1 of Set 11 | champasak
# Processing Record 2 of Set 11 | standish
# Processing Record 3 of Set 11 | moose factory
# Processing Record 4 of Set 11 | bairiki
# Processing Record 5 of Set 11 | napierville
# Processing Record 6 of Set 11 | sulurpeta
# City not found. Skipping...
# Processing Record 7 of Set 11 | poum
# Processing Record 8 of Set 11 | richards bay
# Processing Record 9 of Set 11 | annigeri
# Processing Record 10 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 11 of Set 11 | zharkovskiy
# Processing Record 12 of Set 11 | hvide sande
# Processing Record 13 of Set 11 | moranbah
# Processing Record 14 of Set 11 | geraldton
# Processing Record 15 of Set 11 | pangkalanbuun
# Processing Record 16 of Set 11 | houma
# Processing Record 17 of Set 11 | svetlaya
# Processing Record 18 of Set 11 | freeport
# Processing Record 19 of Set 11 | silvania
# Processing Record 20 of Set 11 | honiara
# Processing Record 21 of Set 11 | goma
# Processing Record 22 of Set 11 | sivas
# Processing Record 23 of Set 11 | suzun
# Processing Record 24 of Set 11 | vao
# Processing Record 25 of Set 11 | kochevo
# Processing Record 26 of Set 11 | kudahuvadhoo
# Processing Record 27 of Set 11 | onega
# Processing Record 28 of Set 11 | segou
# Processing Record 29 of Set 11 | pivijay
# Processing Record 30 of Set 11 | praia da vitoria
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 11 | iralaya
# Processing Record 34 of Set 11 | nevers
# Processing Record 35 of Set 11 | kantang
# Processing Record 36 of Set 11 | grong
# Processing Record 37 of Set 11 | port moresby
# Processing Record 38 of Set 11 | talnakh
# Processing Record 39 of Set 11 | kiama
# Processing Record 40 of Set 11 | pecos
# Processing Record 41 of Set 11 | west wendover
# Processing Record 42 of Set 11 | maine-soroa
# Processing Record 43 of Set 11 | sherghati
# Processing Record 44 of Set 11 | ajdabiya
# Processing Record 45 of Set 11 | isiro
# Processing Record 46 of Set 11 | rusape
# Processing Record 47 of Set 11 | virginia beach
# Processing Record 48 of Set 11 | ulcinj
# Processing Record 49 of Set 11 | warrnambool
# Processing Record 50 of Set 11 | birao
# Processing Record 1 of Set 12 | rezekne
# Processing Record 2 of Set 12 | verkhnevilyuysk
# Processing Record 3 of Set 12 | makurdi
# Processing Record 4 of Set 12 | oktyabrskiy
# Processing Record 5 of Set 12 | emilio carranza
# Processing Record 6 of Set 12 | san cristobal
# Processing Record 7 of Set 12 | pincher creek
# Processing Record 8 of Set 12 | kilindoni
# Processing Record 9 of Set 12 | moa
# Processing Record 10 of Set 12 | caloundra
# Processing Record 11 of Set 12 | warri
# Processing Record 12 of Set 12 | naron
# Processing Record 13 of Set 12 | amelia
# Processing Record 14 of Set 12 | giddalur
# Processing Record 15 of Set 12 | voloshka
# Processing Record 16 of Set 12 | lar
# Processing Record 17 of Set 12 | avanigadda
# Processing Record 18 of Set 12 | erenhot
# Processing Record 19 of Set 12 | casper
# Processing Record 20 of Set 12 | budingen
# Processing Record 21 of Set 12 | la ronge
# Processing Record 22 of Set 12 | methoni
# Processing Record 23 of Set 12 | palmer
# Processing Record 24 of Set 12 | buchanan
# Processing Record 25 of Set 12 | nouadhibou
# Processing Record 26 of Set 12 | pokhara
# Processing Record 27 of Set 12 | abu kamal
# Processing Record 28 of Set 12 | kaeo
# Processing Record 29 of Set 12 | taybad
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | venice
# Processing Record 32 of Set 12 | lazaro cardenas
# Processing Record 33 of Set 12 | siderno
# Processing Record 34 of Set 12 | palora
# Processing Record 35 of Set 12 | isla aguada
# Processing Record 36 of Set 12 | singaparna
# Processing Record 37 of Set 12 | lasa
# Processing Record 38 of Set 12 | hambantota
# Processing Record 39 of Set 12 | haileybury
# Processing Record 40 of Set 12 | ngunguru
# Processing Record 41 of Set 12 | mumford
# Processing Record 42 of Set 12 | sikasso
# Processing Record 43 of Set 12 | anadyr
# Processing Record 44 of Set 12 | burgeo
# Processing Record 45 of Set 12 | dumas
# Processing Record 46 of Set 12 | enshi
# Processing Record 47 of Set 12 | brownwood
# Processing Record 48 of Set 12 | mineiros
# Processing Record 49 of Set 12 | jibuti
# Processing Record 50 of Set 12 | mulchen
# Processing Record 1 of Set 13 | namtsy
# Processing Record 2 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 13 | iqaluit
# Processing Record 6 of Set 13 | aripuana
# Processing Record 7 of Set 13 | general roca
# Processing Record 8 of Set 13 | bonavista
# Processing Record 9 of Set 13 | balaipungut
# Processing Record 10 of Set 13 | we
# City not found. Skipping...
# Processing Record 11 of Set 13 | pabrade
# Processing Record 12 of Set 13 | boende
# Processing Record 13 of Set 13 | cuamba
# Processing Record 14 of Set 13 | ossora
# Processing Record 15 of Set 13 | great yarmouth
# Processing Record 16 of Set 13 | iracoubo
# Processing Record 17 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 13 | ola
# Processing Record 19 of Set 13 | rantepao
# Processing Record 20 of Set 13 | alappuzha
# Processing Record 21 of Set 13 | yelizovo
# Processing Record 22 of Set 13 | touros
# Processing Record 23 of Set 13 | suntar
# Processing Record 24 of Set 13 | wanxian
# Processing Record 25 of Set 13 | gambela
# Processing Record 26 of Set 13 | thinadhoo
# Processing Record 27 of Set 13 | mae chan
# Processing Record 28 of Set 13 | kidal
# Processing Record 29 of Set 13 | monywa
# Processing Record 30 of Set 13 | mahajanga
# Processing Record 31 of Set 13 | springfield
# Processing Record 32 of Set 13 | zhigansk
# Processing Record 33 of Set 13 | benguela
# Processing Record 34 of Set 13 | tambovka
# Processing Record 35 of Set 13 | udachnyy
# Processing Record 36 of Set 13 | qaqortoq
# Processing Record 37 of Set 13 | sibolga
# Processing Record 38 of Set 13 | umm lajj
# Processing Record 39 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 13 | port hueneme
# Processing Record 41 of Set 13 | shahr-e babak
# Processing Record 42 of Set 13 | dunedin
# Processing Record 43 of Set 13 | havoysund
# Processing Record 44 of Set 13 | douentza
# Processing Record 45 of Set 13 | marsaxlokk
# Processing Record 46 of Set 13 | yilan
# Processing Record 47 of Set 13 | henties bay
# Processing Record 48 of Set 13 | mahon
# Processing Record 49 of Set 13 | mantua
# Processing Record 50 of Set 13 | mabaruma
# Processing Record 1 of Set 14 | kijang
# Processing Record 2 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 14 | abeche
# Processing Record 4 of Set 14 | ninh binh
# Processing Record 5 of Set 14 | agbor
# Processing Record 6 of Set 14 | natchez
# Processing Record 7 of Set 14 | norilsk
# Processing Record 8 of Set 14 | vuktyl
# Processing Record 9 of Set 14 | kahului
# Processing Record 10 of Set 14 | antofagasta
# Processing Record 11 of Set 14 | perivolion
# Processing Record 12 of Set 14 | metehara
# City not found. Skipping...
# Processing Record 13 of Set 14 | mecca
# Processing Record 14 of Set 14 | presidencia roque saenz pena
# Processing Record 15 of Set 14 | haines junction
# Processing Record 16 of Set 14 | khilok
# Processing Record 17 of Set 14 | berdigestyakh
# Processing Record 18 of Set 14 | meadow lake
# Processing Record 19 of Set 14 | vostok
# Processing Record 20 of Set 14 | geneva
# Processing Record 21 of Set 14 | kaka
# Processing Record 22 of Set 14 | vardadzor
# Processing Record 23 of Set 14 | nikel
# Processing Record 24 of Set 14 | noumea
# Processing Record 25 of Set 14 | alangalang
# Processing Record 26 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 27 of Set 14 | shar
# Processing Record 28 of Set 14 | milkovo
# Processing Record 29 of Set 14 | parakou
# Processing Record 30 of Set 14 | lidorikion
# City not found. Skipping...
# Processing Record 31 of Set 14 | dulce nombre de culmi
# Processing Record 32 of Set 14 | olavarria
# Processing Record 33 of Set 14 | wamba
# Processing Record 34 of Set 14 | umarkot
# Processing Record 35 of Set 14 | yenisehir
# Processing Record 36 of Set 14 | tual
# Processing Record 37 of Set 14 | kiunga
# Processing Record 38 of Set 14 | omboue
# Processing Record 39 of Set 14 | alyangula
# Processing Record 40 of Set 14 | santa isabel
# Processing Record 41 of Set 14 | luebo
# Processing Record 42 of Set 14 | pacifica
# Processing Record 43 of Set 14 | grand gaube
# Processing Record 44 of Set 14 | honiton
# Processing Record 45 of Set 14 | wawa
# Processing Record 46 of Set 14 | stonewall
# Processing Record 47 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 14 | gwanda
# Processing Record 49 of Set 14 | karasburg
# Processing Record 50 of Set 14 | tuy hoa
# Processing Record 1 of Set 15 | port-gentil
# Processing Record 2 of Set 15 | kyren
# Processing Record 3 of Set 15 | rio grande
# Processing Record 4 of Set 15 | ahuimanu
# Processing Record 5 of Set 15 | vredendal
# Processing Record 6 of Set 15 | salym
# Processing Record 7 of Set 15 | kyrksaeterora
# Processing Record 8 of Set 15 | the valley
# Processing Record 9 of Set 15 | turukhansk
# Processing Record 10 of Set 15 | corrientes
# Processing Record 11 of Set 15 | mabai
# Processing Record 12 of Set 15 | hirara
# Processing Record 13 of Set 15 | simao
# Processing Record 14 of Set 15 | kungurtug
# Processing Record 15 of Set 15 | baykit
# Processing Record 16 of Set 15 | ranong
# Processing Record 17 of Set 15 | ponta delgada
# Processing Record 18 of Set 15 | socorro
# Processing Record 19 of Set 15 | bilibino
# Processing Record 20 of Set 15 | voyvozh
# Processing Record 21 of Set 15 | tangwani
# Processing Record 22 of Set 15 | amahai
# Processing Record 23 of Set 15 | chengde
# Processing Record 24 of Set 15 | port augusta
# Processing Record 25 of Set 15 | atbasar
# Processing Record 26 of Set 15 | ruteng
# Processing Record 27 of Set 15 | ayolas
# Processing Record 28 of Set 15 | weligama
# Processing Record 29 of Set 15 | quatre cocos
# Processing Record 30 of Set 15 | byron bay
# Processing Record 31 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 15 | padong
# Processing Record 33 of Set 15 | elk plain
# Processing Record 34 of Set 15 | gravelbourg
# Processing Record 35 of Set 15 | chebsara
# Processing Record 36 of Set 15 | ust-uda
# Processing Record 37 of Set 15 | ankazoabo
# Processing Record 38 of Set 15 | charters towers
# Processing Record 39 of Set 15 | chumphon
# Processing Record 40 of Set 15 | concepcion del oro
# Processing Record 41 of Set 15 | puerto baquerizo moreno
# Processing Record 42 of Set 15 | san jose
# Processing Record 43 of Set 15 | leshukonskoye
# Processing Record 44 of Set 15 | deputatskiy
# Processing Record 45 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 15 | trairi
# Processing Record 47 of Set 15 | sainte-rose
# Processing Record 48 of Set 15 | hammerfest
# Processing Record 49 of Set 15 | shetpe
# Processing Record 50 of Set 15 | manado
# Processing Record 1 of Set 16 | roebourne
# Processing Record 2 of Set 16 | kavieng
# Processing Record 3 of Set 16 | foz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kruisfontein -34.0033   24.7314     56.88        84         100
# 1         Waipawa -41.4122  175.5153     52.54        70         100
# 2          Pierre  44.3683 -100.3510     56.28        54           0
# 3       Esperance -33.8667  121.9000     61.66        63          93
# 4     Maryborough -25.5333  152.7000     78.12        36           0
# ..            ...      ...       ...       ...       ...         ...
# 688        Shetpe  44.1667   52.1167     63.63        47           1
# 689        Manado   1.4870  124.8455     90.37        58          40
# 690     Roebourne -20.7833  117.1333     88.86        24           6
# 691       Kavieng  -2.5744  150.7967     84.96        67          20
# 692           Foz  43.5692   -7.2544     57.63        84          82
#
#      Wind Speed Country Weather Description                 Date
# 0          1.43      ZA     overcast clouds  2022-09-26 05:09:22
# 1         11.74      NZ     overcast clouds  2022-09-26 05:05:32
# 2          7.00      US           clear sky  2022-09-26 05:09:23
# 3          7.34      AU     overcast clouds  2022-09-26 05:09:23
# 4          8.39      AU           clear sky  2022-09-26 05:09:24
# ..          ...     ...                 ...                  ...
# 688        8.50      KZ           clear sky  2022-09-26 05:27:18
# 689        4.61      ID    scattered clouds  2022-09-26 05:27:18
# 690       13.69      AU           clear sky  2022-09-26 05:28:19
# 691       10.04      PG          few clouds  2022-09-26 05:28:19
# 692        3.78      ES       broken clouds  2022-09-26 05:28:19
#
# [693 rows x 10 columns]

# %%
new_columns = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

city_data_df = city_data_df[new_columns]

city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Kruisfontein      ZA -34.0033   24.7314     56.88        84
# 1               Waipawa      NZ -41.4122  175.5153     52.54        70
# 2                Pierre      US  44.3683 -100.3510     56.28        54
# 3             Esperance      AU -33.8667  121.9000     61.66        63
# 4           Maryborough      AU -25.5333  152.7000     78.12        36
# 5            Butaritari      KI   3.0707  172.7902     82.24        73
# 6          Punta Arenas      CL -53.1500  -70.9167     42.91        70
# 7               Rikitea      PF -23.1203 -134.9692     68.38        60
# 8  Vila Franca Do Campo      PT  37.7167  -25.4333     67.19        75
# 9           Black River      JM  18.0264  -77.8487     79.43        87
#
#    Cloudiness  Wind Speed Weather Description
# 0         100        1.43     overcast clouds
# 1         100       11.74     overcast clouds
# 2           0        7.00           clear sky
# 3          93        7.34     overcast clouds
# 4           0        8.39           clear sky
# 5          82       11.77          light rain
# 6          75       25.32       broken clouds
# 7           0       14.56           clear sky
# 8          80        9.24       broken clouds
# 9         100       11.50     overcast clouds

# %%
# Create the output file (CSV).

output_data_file = "../Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file)
