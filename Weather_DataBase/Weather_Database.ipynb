# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from datetime import datetime
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 735

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# # Deliverable 1

# %%
# Create an empty list to hold the weather data.
city_data = []


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
  
    #Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1


# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | goderich
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 2 of Set 1 | mataura
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 3 of Set 1 | pampierstad
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 4 of Set 1 | habiganj
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}
# moderate rain
# --------------------------------------------------
# Processing Record 5 of Set 1 | divnomorskoye
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}
# light rain
# --------------------------------------------------
# Processing Record 6 of Set 1 | vaini
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 7 of Set 1 | mitchell
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 8 of Set 1 | alta floresta
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 9 of Set 1 | busselton
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 10 of Set 1 | yershov
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 11 of Set 1 | chuy
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 12 of Set 1 | thompson
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 13 of Set 1 | yumen
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 14 of Set 1 | salalah
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 15 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 1 | victoria
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 17 of Set 1 | new norfolk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 18 of Set 1 | paamiut
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}
# moderate rain
# --------------------------------------------------
# Processing Record 19 of Set 1 | hilo
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 20 of Set 1 | haines junction
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 21 of Set 1 | westport
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | alekseyevskaya
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | cape town
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 26 of Set 1 | saint george
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 27 of Set 1 | kars
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 28 of Set 1 | cap malheureux
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 29 of Set 1 | bereda
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 30 of Set 1 | albany
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 31 of Set 1 | alofi
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 32 of Set 1 | nikolskoye
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 33 of Set 1 | hermanus
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 34 of Set 1 | ushuaia
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 35 of Set 1 | severo-kurilsk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 36 of Set 1 | hofn
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 37 of Set 1 | longyearbyen
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 38 of Set 1 | isiro
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 39 of Set 1 | mazyr
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 40 of Set 1 | torbay
# [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}, {'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09n'}]
# <class 'list'>
# 3
# {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}
# fog
# --------------------------------------------------
# Processing Record 41 of Set 1 | port alfred
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 42 of Set 1 | dunedin
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 43 of Set 1 | berlevag
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 44 of Set 1 | eyl
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 45 of Set 1 | hami
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 46 of Set 1 | lodi
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 47 of Set 1 | rikitea
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 48 of Set 1 | aklavik
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | jamestown
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 1 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 2 | saint-philippe
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 3 of Set 2 | tuktoyaktuk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 4 of Set 2 | punta arenas
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 5 of Set 2 | airai
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 6 of Set 2 | feijo
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 7 of Set 2 | inhambane
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 8 of Set 2 | lerwick
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 9 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 2 | mount gambier
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | atuona
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 13 of Set 2 | broken hill
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 14 of Set 2 | bambous virieux
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 15 of Set 2 | lavrentiya
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 16 of Set 2 | kaohsiung
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 17 of Set 2 | provideniya
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 18 of Set 2 | chokurdakh
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 19 of Set 2 | hithadhoo
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 20 of Set 2 | cleethorpes
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 21 of Set 2 | rawson
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 22 of Set 2 | nicoya
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 23 of Set 2 | mar del plata
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 24 of Set 2 | hobart
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 25 of Set 2 | gushi
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 26 of Set 2 | kahului
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 27 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 2 | hasaki
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 29 of Set 2 | uddevalla
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | odweyne
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 32 of Set 2 | galesong
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 33 of Set 2 | saldanha
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | puerto ayora
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 36 of Set 2 | sinnamary
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 37 of Set 2 | caconda
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 38 of Set 2 | bluff
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 39 of Set 2 | kapaa
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 40 of Set 2 | sao filipe
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 41 of Set 2 | jiuquan
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 42 of Set 2 | taoudenni
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 43 of Set 2 | turbat
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 44 of Set 2 | bengkulu
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 45 of Set 2 | praia da vitoria
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 46 of Set 2 | mabaruma
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | bredasdorp
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 49 of Set 2 | bairiki
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 50 of Set 2 | honiara
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 1 of Set 3 | matara
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 2 of Set 3 | ponta pora
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 3 of Set 3 | eenhana
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 4 of Set 3 | namatanai
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 5 of Set 3 | leiyang
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 6 of Set 3 | leningradskiy
# [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}]
# <class 'list'>
# 1
# {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}
# light snow
# --------------------------------------------------
# Processing Record 7 of Set 3 | port hedland
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 8 of Set 3 | dakar
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 9 of Set 3 | kaitangata
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 10 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 3 | srednekolymsk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 12 of Set 3 | butaritari
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 13 of Set 3 | mantua
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 14 of Set 3 | altamont
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 15 of Set 3 | grand gaube
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 16 of Set 3 | chik
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 17 of Set 3 | bilibino
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 18 of Set 3 | worland
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 19 of Set 3 | rosarito
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | khatanga
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 22 of Set 3 | arraial do cabo
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 23 of Set 3 | sovetsk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | tura
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}
# moderate rain
# --------------------------------------------------
# Processing Record 26 of Set 3 | babu
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 27 of Set 3 | kodiak
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 28 of Set 3 | arona
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}
# moderate rain
# --------------------------------------------------
# Processing Record 29 of Set 3 | sawakin
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 30 of Set 3 | port lincoln
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 31 of Set 3 | san patricio
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 32 of Set 3 | saskylakh
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 33 of Set 3 | killybegs
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | sorland
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 36 of Set 3 | kruisfontein
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 37 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 3 | vostok
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 39 of Set 3 | tiarei
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 40 of Set 3 | kurilsk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 41 of Set 3 | basay
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 42 of Set 3 | qaanaaq
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 43 of Set 3 | katsuura
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 44 of Set 3 | tasiilaq
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 45 of Set 3 | lebu
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 46 of Set 3 | cherskiy
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 47 of Set 3 | awjilah
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 48 of Set 3 | fortuna
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 49 of Set 3 | tarko-sale
# [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}]
# <class 'list'>
# 1
# {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}
# light snow
# --------------------------------------------------
# Processing Record 50 of Set 3 | gouyave
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 1 of Set 4 | bethel
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 2 of Set 4 | myaundzha
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 3 of Set 4 | luderitz
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 4 of Set 4 | quatre cocos
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 5 of Set 4 | huazolotitlan
# City not found. Skipping...
# Processing Record 6 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 4 | codrington
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 8 of Set 4 | steinbach
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 9 of Set 4 | sitka
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 10 of Set 4 | coahuayana
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 11 of Set 4 | nemuro
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 12 of Set 4 | yar-sale
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 13 of Set 4 | dauriya
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 14 of Set 4 | kavieng
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 15 of Set 4 | yellowknife
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 16 of Set 4 | bubaque
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}
# moderate rain
# --------------------------------------------------
# Processing Record 17 of Set 4 | turukhansk
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 18 of Set 4 | koslan
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 19 of Set 4 | east london
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 20 of Set 4 | cabo san lucas
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 21 of Set 4 | tomatlan
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 22 of Set 4 | ambilobe
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 23 of Set 4 | sikea
# City not found. Skipping...
# Processing Record 24 of Set 4 | yichang
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 25 of Set 4 | urumqi
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 26 of Set 4 | sibolga
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 27 of Set 4 | channel-port aux basques
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 28 of Set 4 | anloga
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 29 of Set 4 | tocopilla
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 30 of Set 4 | saint-pierre
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 31 of Set 4 | dali
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 32 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 4 | druzhba
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 35 of Set 4 | jalu
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 36 of Set 4 | lampazos de naranjo
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 37 of Set 4 | pilar
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}
# few clouds
# --------------------------------------------------
# Processing Record 38 of Set 4 | lorengau
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# ...
# Processing Record 21 of Set 14 | jasper
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 22 of Set 14 | andradas
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 23 of Set 14 | yelizovo
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 24 of Set 14 | zhaodong
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 25 of Set 14 | xianyang
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 26 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 14 | boca do acre
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 28 of Set 14 | fort wellington
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 29 of Set 14 | den helder
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 30 of Set 14 | yeppoon
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 31 of Set 14 | torrevieja
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 32 of Set 14 | wanxian
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 33 of Set 14 | abdanan
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 34 of Set 14 | ulaangom
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}
# scattered clouds
# --------------------------------------------------
# Processing Record 35 of Set 14 | neyshabur
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 36 of Set 14 | toplita
# City not found. Skipping...
# Processing Record 37 of Set 14 | kitakata
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 38 of Set 14 | koumac
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 39 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 40 of Set 14 | anchorage
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 41 of Set 14 | jaru
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 42 of Set 14 | miri
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 43 of Set 14 | kyshtovka
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 44 of Set 14 | pavda
# City not found. Skipping...
# Processing Record 45 of Set 14 | fort nelson
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 46 of Set 14 | richards bay
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 47 of Set 14 | susangerd
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 48 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 49 of Set 14 | sobolevo
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 50 of Set 14 | areosa
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 1 of Set 15 | xuddur
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 2 of Set 15 | moose factory
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 3 of Set 15 | ewa beach
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}
# broken clouds
# --------------------------------------------------
# Processing Record 4 of Set 15 | fort saint james
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 5 of Set 15 | kitui
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 6 of Set 15 | ferry pass
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 7 of Set 15 | port-gentil
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}
# light rain
# --------------------------------------------------
# Processing Record 8 of Set 15 | nyurba
# [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}]
# <class 'list'>
# 1
# {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}
# light snow
# --------------------------------------------------
# Processing Record 9 of Set 15 | wajir
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 10 of Set 15 | sukhumi
# [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}
# moderate rain
# --------------------------------------------------
# Processing Record 11 of Set 15 | qui nhon
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}
# light rain
# --------------------------------------------------
# Processing Record 12 of Set 15 | canton
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 13 of Set 15 | george
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 14 of Set 15 | benjamin hill
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 15 of Set 15 | whitehorse
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 16 of Set 15 | beitbridge
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 17 of Set 15 | bonthe
# [{'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10n'}]
# <class 'list'>
# 1
# {'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10n'}
# heavy intensity rain
# --------------------------------------------------
# Processing Record 18 of Set 15 | beruwala
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 19 of Set 15 | dawlatabad
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}
# clear sky
# --------------------------------------------------
# Processing Record 20 of Set 15 | mangan
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 21 of Set 15 | chiusi
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}
# overcast clouds
# --------------------------------------------------
# Processing Record 22 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 15 | atkinson
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 24 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 25 of Set 15 | ruwi
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
# <class 'list'>
# 1
# {'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}
# few clouds
# --------------------------------------------------
# Processing Record 26 of Set 15 | burica
# City not found. Skipping...
# Processing Record 27 of Set 15 | bardiyah
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 28 of Set 15 | aden
# [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}]
# <class 'list'>
# 1
# {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}
# light rain
# --------------------------------------------------
# Processing Record 29 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 30 of Set 15 | inirida
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]
# <class 'list'>
# 1
# {'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}
# broken clouds
# --------------------------------------------------
# Processing Record 31 of Set 15 | oktyabrskiy
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]
# <class 'list'>
# 1
# {'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}
# overcast clouds
# --------------------------------------------------
# Processing Record 32 of Set 15 | pueblo
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
# <class 'list'>
# 1
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}
# clear sky
# --------------------------------------------------
# Processing Record 33 of Set 15 | kargapolye
# City not found. Skipping...
# Processing Record 34 of Set 15 | camacha
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# Processing Record 35 of Set 15 | tamandare
# [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]
# <class 'list'>
# 1
# {'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}
# scattered clouds
# --------------------------------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Goderich  43.7501  -81.7165     47.91        93         100
# 1          Mataura -46.1927  168.8643     59.54        55          85
# 2      Pampierstad -27.7832   24.6877     58.37        26           0
# 3         Habiganj  24.3833   91.4167     84.56        75         100
# 4    Divnomorskoye  44.5011   38.1353     57.25        79          20
# ..             ...      ...       ...       ...       ...         ...
# 659        Inirida   3.8653  -67.9239     74.70        93          60
# 660    Oktyabrskiy  54.4815   53.4710     68.52        25         100
# 661         Pueblo  38.2545 -104.6091     72.36        28           0
# 662        Camacha  33.0833  -16.3333     69.22        73          40
# 663      Tamandare  -8.7597  -35.1047     75.09        83          26
#
#      Wind Speed Country Weather Description                 Date
# 0          2.30      CA     overcast clouds  2022-09-24 03:46:36
# 1          5.03      NZ     overcast clouds  2022-09-24 03:48:20
# 2         10.65      ZA           clear sky  2022-09-24 03:48:21
# 3          5.01      BD       moderate rain  2022-09-24 03:48:21
# 4          4.99      RU          light rain  2022-09-24 03:48:21
# ..          ...     ...                 ...                  ...
# 659        3.38      CO       broken clouds  2022-09-24 04:10:44
# 660       11.77      RU     overcast clouds  2022-09-24 04:10:45
# 661        8.05      US           clear sky  2022-09-24 04:10:45
# 662        6.91      PT    scattered clouds  2022-09-24 04:10:46
# 663        8.14      BR    scattered clouds  2022-09-24 04:10:46
#
# [664 rows x 10 columns]

# %%
new_columns = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

city_data_df = city_data_df[new_columns]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Goderich      CA  43.7501  -81.7165     47.91        93         100
# 1        Mataura      NZ -46.1927  168.8643     59.54        55          85
# 2    Pampierstad      ZA -27.7832   24.6877     58.37        26           0
# 3       Habiganj      BD  24.3833   91.4167     84.56        75         100
# 4  Divnomorskoye      RU  44.5011   38.1353     57.25        79          20
# 5          Vaini      TO -21.2000 -175.2000     78.96        83          75
# 6       Mitchell      US  43.7094  -98.0298     62.58        59           0
# 7  Alta Floresta      BR  -9.8756  -56.0861     70.84        89          33
# 8      Busselton      AU -33.6500  115.3333     60.01        46          26
# 9        Yershov      RU  51.3513   48.2766     58.66        81           9
#
#    Wind Speed Weather Description
# 0        2.30     overcast clouds
# 1        5.03     overcast clouds
# 2       10.65           clear sky
# 3        5.01       moderate rain
# 4        4.99          light rain
# 5        8.05       broken clouds
# 6        8.05           clear sky
# 7        3.78    scattered clouds
# 8       12.66    scattered clouds
# 9       15.70           clear sky

# %%
# Create the output file (CSV).

output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file)
